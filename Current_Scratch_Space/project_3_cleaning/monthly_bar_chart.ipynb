# %%
# Dependencies and Setup
import pandas as pd 
from pathlib import Path
import warnings
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# Pull CSV
revenues_df = pd.read_csv("Resources/master_monthly_revenue.csv")
revenues_df.head()
# Out:
#        Month  Year  Cumulative Gross % of Year  Releases  Average
# 0   December  2023         321770088      3.8%        82  3924025
# 1   November  2023         551961137      6.5%       111  4972622
# 2    October  2023         556040943      6.6%       115  4835138
# 3  September  2023         472947170      5.6%       116  4077130
# 4     August  2023         812833316      9.6%       104  7815704

# %%
reverse_rev = revenues_df.iloc[::-1]
reverse_rev
# Out:
#         Month  Year  Cumulative Gross % of Year  Releases   Average
# 59    January  2019         812849718      7.2%       161   5048756
# 58   February  2019         624462229      5.5%       147   4248042
# 57      March  2019         962715490      8.5%       192   5014143
# 56      April  2019        1034983338      9.1%       220   4704469
# 55        May  2019        1077667188      9.5%       225   4789631
# 54       June  2019        1149048054     10.1%       192   5984625
# 53       July  2019        1288196026     11.3%       190   6779979
# 52     August  2019         837630353      7.4%       211   3969812
# 51  September  2019         686794246        6%       204   3366638
# 50    October  2019         781640026      6.9%       217   3602027
# 49   November  2019         959213976      8.4%       189   5075206
# 48   December  2019        1148160245     10.1%       167   6875211
# 47    January  2020         897742569     42.5%       146   6148921
# ...

# %%
plt.figure(figsize=(20, 6))
sns.barplot(data = reverse_rev,
            x = 'Month',
            y = 'Cumulative Gross',
            hue = 'Year',
            ci = None,
            color = 'salmon'
            )
plt.rcParams["figure.figsize"] = (1500, 600)
plt.show()
